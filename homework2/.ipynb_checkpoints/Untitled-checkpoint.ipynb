# %%
import numpy as np
import pandas as pd

n_obs = 50 #per group
periods = 11

#Group coefficients
gc = [(1.0, 0.5, 0.0),
      (0.0, 0.0, 1.5)]
gc_np = np.array(gc).transpose()
gps = len(gc)

#Creating panel data over time in long format
t = np.tile(range(periods), n_obs*gps)
id_col = np.repeat(range(n_obs*gps), periods)
group_col = np.repeat(range(gps), n_obs*periods)
t_dat = pd.DataFrame( zip(id_col, group_col, t), columns=['ID','group','t'])

#Latent classes (long format)
lat_np = pd.get_dummies(t_dat.group).to_numpy()

#Prepping the time design matrix
center = periods/2
t_dat['t0'] = 1
center = periods/2
t_dat['t1'] = (t_dat['t']-center)/center
t_dat['t2'] = t_dat['t1']**2
vars = ['t0','t1','t2']
t_np = t_dat[vars].to_numpy() #this is our design matrix

#Now creatings the outcome data
pred_full = t_np.dot(gc_np) #This gives us predictions for both groups
y = (pred_full * lat_np).sum(axis=1) #Element wise multiplication here

#Add some error to the true underlying curves
y_werr = y + np.random.uniform(low=-0.05, high=0.05, size=y.shape)
t_dat['outcome'] = y_werr

#Show what the data looks like in the end
t_dat
# Out:
#       ID  group   t  t0        t1        t2   outcome
# 0      0      0   0   1 -1.000000  1.000000  0.481696
# 1      0      0   1   1 -0.818182  0.669421  0.635849
# 2      0      0   2   1 -0.636364  0.404959  0.682634
# 3      0      0   3   1 -0.454545  0.206612  0.750426
# 4      0      0   4   1 -0.272727  0.074380  0.836104
# ...   ..    ...  ..  ..       ...       ...       ...
# 1095  99      1   6   1  0.090909  0.008264  0.062181
# 1096  99      1   7   1  0.272727  0.074380  0.095732
# 1097  99      1   8   1  0.454545  0.206612  0.284944
# 1098  99      1   9   1  0.636364  0.404959  0.557686
# 1099  99      1  10   1  0.818182  0.669421  0.986899
#
# [1100 rows x 7 columns]

# %%
 pd.get_dummies(t_dat.group)
# Out:
#       0  1
# 0     1  0
# 1     1  0
# 2     1  0
# 3     1  0
# 4     1  0
# ...  .. ..
# 1095  0  1
# 1096  0  1
# 1097  0  1
# 1098  0  1
# 1099  0  1
#
# [1100 rows x 2 columns]

# %%
values.shape
# Out:
# (12868, 43)

# %%
import matplotlib.pyplot as plt
import numpy as np

values = pd.read_csv('matrix_for_cluster.csv', index_col=0).values

y = [(1,2,3,9),(1,1,2,4), (1,1,2,4)]
x = list(range(4))


fig, ax = plt.subplots()

for i in range(len(y)):
    ax.plot(x, y[i])

plt.show()

# %%
x
# Out:
# [0, 1, 2]
